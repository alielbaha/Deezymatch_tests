# %%
pip install deep-phonemizer
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.3 MB/s eta 0:00:00
# ...

# %%
from dp.phonemizer import Phonemizer
# Out:
# /usr/local/lib/python3.11/dist-packages/dp/model/model.py:306: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
phonemizer = Phonemizer.from_checkpoint('latin_ipa_forward.pt')

# %%
phonemizer("Hello world!",lang="fr")
# Out:
# 'ɛlo wɔʁld!'

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# accelerate==1.3.0
# aiohappyeyeballs==2.5.0
# aiohttp==3.11.13
# aiosignal==1.3.2
# alabaster==1.0.0
# albucore==0.0.23
# albumentations==2.0.5
# ale-py==0.10.2
# altair==5.5.0
# annotated-types==0.7.0
# anyio==3.7.1
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# array_record==0.6.0
# arviz==0.20.0
# astropy==7.0.1
# astropy-iers-data==0.2025.3.10.0.29.26
# astunparse==1.6.3
# atpublic==4.1.0
# attrs==25.1.0
# audioread==3.0.1
# autograd==1.7.0
# babel==2.17.0
# backcall==0.2.0
# beautifulsoup4==4.13.3
# betterproto==2.0.0b6
# bigframes==1.38.0
# bigquery-magics==0.6.0
# bleach==6.2.0
# blinker==1.9.0
# blis==0.7.11
# blosc2==3.2.0
# bokeh==3.6.3
# Bottleneck==1.4.2
# bqplot==0.12.44
# branca==0.8.1
# CacheControl==0.14.2
# cachetools==5.5.2
# catalogue==2.0.10
# certifi==2025.1.31
# cffi==1.17.1
# chardet==5.2.0
# charset-normalizer==3.4.1
# chex==0.1.89
# clarabel==0.10.0
# click==8.1.8
# cloudpathlib==0.21.0
# cloudpickle==3.1.1
# cmake==3.31.6
# ...

# %%
import requests

url = 'https://raw.githubusercontent.com/CUNY-CL/wikipron/refs/heads/master/data/scrape/tsv/fra_latn_broad_filtered.tsv'
response = requests.get(url)
data = response.text

# %%
lines = data.strip().split('\n')

uniquephonemes = set()

for line in lines:
    parts = line.split('\t')
    if len(parts) == 2:
        word, transcription = parts
        phonemes = transcription.split()

        uniquephonemes.update(phonemes)
phoneme_list = sorted(uniquephonemes)
phoneme_list
# Out:
# ['a',
#  'b',
#  'd',
#  'e',
#  'f',
#  'i',
#  'j',
#  'k',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't',
#  'u',
#  'v',
#  'w',
#  'y',
#  'z',
#  'ø',
#  'ŋ',
#  'œ',
#  'œ̃',
#  'ɑ',
#  'ɑ̃',
#  'ɔ',
#  'ɔ̃',
#  'ə',
#  'ɛ',
#  'ɛː',
#  'ɛ̃',
#  'ɡ',
#  'ɥ',
#  'ɲ',
#  'ʁ',
#  'ʃ',
#  'ʒ',
#  '‿']

# %%
len(phoneme_list)
# Out:
# 40

# %%
fr_phonemes = ['a',
 'b',
 'd',
 'e',
 'f',
 'i',
 'j',
 'k',
 'l',
 'm',
 'n',
 'o',
 'p',
 'r',
 's',
 't',
 'u',
 'v',
 'w',
 'y',
 'z',
 'ø',
 'ŋ',
 'œ',
 'œ̃',
 'ɑ',
 'ɑ̃',
 'ɔ',
 'ɔ̃',
 'ə',
 'ɛ',
 'ɛː',
 'ɛ̃',
 'ɡ',
 'ɥ',
 'ɲ',
 'ʁ',
 'ʃ',
 'ʒ',
 '‿']

# %%
import re

def split_phon(text,phoneme_list):
    def get_phontrans(text, phoneme_list):
        words = text.split()
        transcriptions = phonemizer(words, lang='fr')

        phoneme_list = sorted(phoneme_list, key=len, reverse=True)

        formatted_transcriptions = {}
        unique_phonemes = set()
        for word, transcription in zip(words, transcriptions):

            spaced_transcription = ' '.join(re.findall('|'.join(map(re.escape, phoneme_list)), transcription))
            formatted_transcriptions[word] = spaced_transcription
            unique_phonemes.update(spaced_transcription.split())

        return formatted_transcriptions, sorted(unique_phonemes)

    out = get_phontrans(text, phoneme_list)
    transcription = out[0]
    for word, phonetic in transcription.items():
        print(f"{word}: {phonetic}")
    print(out[1])

# %%
split_phon("Deux Mulets cheminaient, l’un d’avoine chargé, L’autre portant l’argent de la gabelle. Celui-ci, glorieux d’une charge si belle, N’eût voulu pour beaucoup en être soulagé. Il marchait d’un pas relevé, Et faisait sonner sa sonnette ; Quand , l’ennemi se présentant, Comme il en voulait à l’argent,Sur le Mulet du fisc une troupe se jette, Le saisit au frein et l’arrête. Le mulet, en se défendant, Se sent percé de coups ; il gémit, il soupire. « Est-ce donc là, dit-il, ce qu’on m’avait promis ? Ce Mulet qui me suit du danger se retire ; Et moi j’y tombe et je péris ! – Ami, lui dit son camarade, Il n’est pas toujours bon d’avoir un haut emploi : Si tu n’avais servi  qu’un meunier, comme moi, Tu ne serais pas si malade.",fr_phonemes)
# Out:
# Deux: d ø
# Mulets: m y l ɛ
# cheminaient,: ʃ ə m i n ɛ
# l’un: l œ̃
# d’avoine: d a v w a n
# chargé,: ʃ a ʁ ʒ e
# L’autre: l o t ʁ
# portant: p ɔ ʁ t ɑ̃
# l’argent: l a ʁ ʒ
# de: d ə
# la: l a
# gabelle.: ɡ a b ɛ l
# Celui-ci,: s ə l ɥ i s i
# glorieux: ɡ l ɔ ʁ j ø
# d’une: d y n
# charge: ʃ a ʁ ʒ
# si: s i
# belle,: b ɛ l
# N’eût: n ø
# voulu: v u l y
# pour: p u ʁ
# beaucoup: b o k u
# en: ɑ̃
# être: d ɛ t
# soulagé.: s u l a ʒ e
# Il: i
# marchait: m a ʁ ʃ ɛ
# d’un: d œ̃
# pas: p a
# relevé,: ʁ ə l ə v e
# Et: e
# faisait: f ə z ɛ
# sonner: s ɔ n e
# sa: s a
# sonnette: s ɔ n ɛ t
# ;:
# Quand: e k ɑ̃
# ,:
# l’ennemi: l ɛ n m i
# se: s ə
# présentant,: p ʁ e z ɑ̃ t ɑ̃
# Comme: k ɔ m
# il: i
# voulait: v u l ɛ
# à: a
# l’argent,Sur: l a ʁ ʒ s y ʁ
# le: l
# Mulet: m y l ɛ
# du: d y
# fisc: f i s k
# une: y n
# troupe: t ʁ u p
# jette,: ʒ ɛ t
# Le: l
# saisit: s ɛ z i
# au: o
# frein: f ʁ ɛ̃
# et: e
# l’arrête.: l a ʁ ɛ t
# mulet,: m y l ɛ
# défendant,: d e f ɑ̃ d ɑ̃
# Se: s ə
# ...

# %% [markdown]
# ### V. Hugo : Demain, dès l’aube

# %% [markdown]
# Demain, dès l’aube, à l’heure où blanchit la campagne,
# Je partirai. Vois-tu, je sais que tu m’attends.
# J’irai par la forêt, j’irai par la montagne.
# Je ne puis demeurer loin de toi plus longtemps.
#
# Je marcherai les yeux fixés sur mes pensées,
# Sans rien voir au dehors, sans entendre aucun bruit,
# Seul, inconnu, le dos courbé, les mains croisées,
# Triste, et le jour pour moi sera comme la nuit.
#
# Je ne regarderai ni l’or du soir qui tombe,
# Ni les voiles au loin descendant vers Harfleur,
# Et, quand j’arriverai, je mettrai sur ta tombe
# Un bouquet de houx vert et de bruyère en fleur

# %%
phonemizer("Demain, dès l’aube, à l’heure où blanchit la campagne, Je partirai. Vois-tu, je sais que tu m’attends. J’irai par la forêt, j’irai par la montagne. Je ne puis demeurer loin de toi plus longtemps. Je marcherai les yeux fixés sur mes pensées, Sans rien voir au dehors, sans entendre aucun bruit, Seul, inconnu, le dos courbé, les mains croisées, Triste, et le jour pour moi sera comme la nuit. Je ne regarderai ni l’or du soir qui tombe, Ni les voiles au loin descendant vers Harfleur, Et, quand j’arriverai, je mettrai sur ta tombe Un bouquet de houx vert et de bruyère en fleur ",lang="fr")
# Out:
# 'dəmɛ̃, dɛ lob, a lœʁ u blɑ̃ʃi la kɑ̃paɲ, ʃ paʁtiʁe. vwa-ty, ʃ sɛ kə ty matɑ̃. ʒiʁe paʁ la fɔʁɛ, ʒiʁe paʁ la mɔ̃taɲ. ʃ nə pɥi dəmœʁe lwɛ̃ də twa ply lɔ̃tɑ̃. ʃ maʁʃəʁe le jø fikse syʁ me pɑ̃se, sɑ̃ ʁjɛ̃ vwaʁ o dəɔʁ, sɑ̃ ɑ̃tɑ̃dʁ okœ̃ bʁɥi, sœl, ɛ̃kɔny, l do kuʁbe, le mɛ̃ kʁwaze, tʁist, e l ʒuʁ puʁ mwa səʁa kɔm la nwi. ʃ nə ʁəɡaʁdəʁe ni lɔʁ dy swar ki tɔ̃b, ni le vwal o lwɛ̃ desɑ̃dɑ̃ vɛʁ aʁflœʁ, e, ekɑ̃ ʒaʁivʁe, ʃ mɛtʁe syʁ ta tɔ̃b œ̃ bukɛ də u vɛʁ e də bʁɥijɛʁ ɑ̃ flœʁ '

# %%
split_phon("Demain, dès l’aube, à l’heure où blanchit la campagne, Je partirai. Vois-tu, je sais que tu m’attends. J’irai par la forêt, j’irai par la montagne. Je ne puis demeurer loin de toi plus longtemps. Je marcherai les yeux fixés sur mes pensées, Sans rien voir au dehors, sans entendre aucun bruit, Seul, inconnu, le dos courbé, les mains croisées, Triste, et le jour pour moi sera comme la nuit. Je ne regarderai ni l’or du soir qui tombe, Ni les voiles au loin descendant vers Harfleur, Et, quand j’arriverai, je mettrai sur ta tombe Un bouquet de houx vert et de bruyère en fleur",fr_phonemes)
# Out:
# Demain,: d ə m ɛ̃
# dès: d ɛ
# l’aube,: l o b
# à: a
# l’heure: l œ ʁ
# où: u
# blanchit: b l ɑ̃ ʃ i
# la: l a
# campagne,: k ɑ̃ p a ɲ
# Je: ʃ
# partirai.: p a ʁ t i ʁ e
# Vois-tu,: v w a t y
# je: ʃ
# sais: s ɛ
# que: k ə
# tu: t y
# m’attends.: m a t ɑ̃
# J’irai: ʒ i ʁ e
# par: p a ʁ
# forêt,: f ɔ ʁ ɛ
# j’irai: ʒ i ʁ e
# montagne.: m ɔ̃ t a ɲ
# ne: n ə
# puis: p ɥ i
# demeurer: d ə m œ ʁ e
# loin: l w ɛ̃
# de: d ə
# toi: t w a
# plus: p l y
# longtemps.: l ɔ̃ t ɑ̃
# marcherai: m a ʁ ʃ ə ʁ e
# les: l e
# yeux: j ø
# fixés: f i k s e
# sur: s y ʁ
# mes: m e
# pensées,: p ɑ̃ s e
# Sans: s ɑ̃
# rien: ʁ j ɛ̃
# voir: v w a ʁ
# au: o
# dehors,: d ə ɔ ʁ
# sans: s ɑ̃
# entendre: ɑ̃ t ɑ̃ d ʁ
# aucun: o k œ̃
# bruit,: b ʁ ɥ i
# Seul,: s œ l
# inconnu,: ɛ̃ k ɔ n y
# le: l
# dos: d o
# courbé,: k u ʁ b e
# mains: m ɛ̃
# croisées,: k ʁ w a z e
# Triste,: t ʁ i s t
# et: e
# jour: ʒ u ʁ
# pour: p u ʁ
# moi: m w a
# sera: s ə ʁ a
# comme: k ɔ m
# nuit.: n w i
# regarderai: ʁ ə ɡ a ʁ d ə ʁ e
# ...

# %%
phonemizer("é è ê ai ais ait er ez",lang="fr")
# Out:
# 'e ɛ ɛ e ɛ ɛ ɛʁ e'

# %%
phonemizer("u eu ju jeu ",lang="fr")
# Out:
# 'y y ʒy ʒø '

# %%
phonemizer("ein ain",lang="fr")
# Out:
# 'ɛ̃ ɛ̃'

# %%
phonemizer("eine aine seine saine",lang="fr")
# Out:
# 'ɛn ɛn sɛn sɛn'

# %%
phonemizer("u muet",lang="fr")
# Out:
# 'y myɛ'

# %%
phonemizer("eu eux",lang="fr")
# Out:
# 'y ø'

# %%
phonemizer("jeu jeux ",lang="fr")
# Out:
# 'ʒø ʒø '

# %%
phonemizer("chanter",lang="fr")
# Out:
# 'ʃɑ̃te'

# %%
phonemizer("j je ja ji ju jy",lang="fr")
# Out:
# 'ʒi ʃ ʒa ʒi ʒy ʒi'

# %%
phonemizer("ch sh cha chi che",lang="fr")
# Out:
# 'seaʃ ʃ ʃa ʃi ʃə'

# %%
phonemizer("jus",lang="fr")
# Out:
# 'ʒy'

# %%
phonemizer("je suis",lang="fr")
# Out:
# 'ʃ sɥi'

# %%
phonemizer("julien",lang="fr")
# Out:
# 'ʒyljɛ̃'

# %%
phonemizer("juliette",lang="fr")
# Out:
# 'ʒyljɛt'

# %%
phonemizer("gérer",lang="fr")
# Out:
# 'ʒeʁe'

# %%
phonemizer("j",lang="fr")
# Out:
# 'ʒi'

# %%
phonemizer("jeton",lang="fr")
# Out:
# 'ʒətɔ̃'

# %%
phonemizer("geant",lang="fr")
# Out:
# 'ʒɑ̃'

# %%
phonemizer("gean",lang="fr")
# Out:
# 'ʒin'

# %%
phonemizer("thibault tibaut tybaut tybault thibo thibeau",lang="fr")
# Out:
# 'tibo tibo tibo tibo tibo tibo'

# %%
phonemizer("christine christinn / christin christain chritein",lang="fr")
# Out:
# 'kʁistin kʁistin / kʁistɛ̃ kʁistɛ̃ kʁitɛ̃'

# %%
phonemizer("faisait",lang="fr")
# Out:
# 'fəzɛ'

# %%
phonemizer("ban",lang="fr")
# Out:
# 'bɑ̃'

# %%
phonemizer("amélie",lang="fr")
# Out:
# 'ameli'

# %%
phonemizer("arianne arienne arnaud arnaude",lang="fr")
# Out:
# 'aʁjan aʁjɛn aʁno aʁnod'

# %%
phonemizer("françois benoit ",lang="fr")
# Out:
# 'fʁɑ̃swa bənwa '

# %%
phonemizer("hubert hilbert albert aubert robert",lang="fr")
# Out:
# 'ybɛʁ ilbɛʁ albɛʁ obɛʁ ʁɔbɛʁ'

# %%
phonemizer("jonathan jonatan jonaton",lang="fr")
# Out:
# 'ʒɔnatɑ̃ ʒɔnatɑ̃ ʒɔnatɔ̃'

# %%
phonemizer("cécile cécile sésile séssile sécyl",lang="fr")
# Out:
# 'sesil sesil sezil sesil sesil'

# %%
phonemizer("benoit",lang="fr")
# Out:
# 'bənwa'

# %%
phonemizer("œuf uf euf ef of",lang="fr")
# Out:
# 'œf yf œf ef ɔ'

# %%
phonemizer("montagne",lang="fr")
# Out:
# 'mɔ̃taɲ'

# %%
phonemizer("lyon",lang="fr")
# Out:
# 'lijɔ̃'

# %%
phonemizer("mot mau maux mau meau mo",lang="fr")
# Out:
# 'mo mo mo mo mo mo'

# %%
replacements = {
    "a": ["A"],
    "b": ["B"],
    "d": ["D"],
    "e": ["E", "É", "È", "Ê", "AI"],
    "f": ["F", "PH"],
    "i": ["I", "Y"],
    "j": ["Y"],
    "k": ["K", "C", "QU"],
    "l": ["L", "LL"],
    "m": ["M", "MM"],
    "n": ["N", "NN"],
    "o": ["O", "AU", "EAU"],
    "p": ["P"],
    "r": ["R", "RR"],
    "s": ["S", "SS"],
    "t": ["T", "TT"],
    "u": ["OU"],
    "v": ["V"],
    "w": ["W"],
    "y": ["U"],
    "z": ["Z", "S"],
    "ø": ["EU", "ŒU"],
    "ŋ": ["NG"],
    "œ": ["Œ", "EU", "ŒU"],
    "œ̃": ["UN", "UM"],
    "ɑ": ["A"],
    "ɑ̃": ["AN", "AM", "EN", "EM"],
    "ɔ": ["O"],
    "ɔ̃": ["ON", "OM"],
    "ə": ["E"],
    "ɛ": ["E", "É", "È", "Ê", "AI"],
    "ɛː": ["E", "É", "È", "Ê", "AI"],
    "ɛ̃": ["IN", "IM", "AIN", "EIN"],
    "ɡ": ["G", "GU"],
    "ɥ": ["U", "HU"],
    "ɲ": ["GN"],
    "ʁ": ["R"],
    "ʃ": ["CH","SH"],
    "ʒ": ["J", "G", "GE"],
}

# %%
pip install graphviz

# %%
from graphviz import Digraph

def gen_tree(name, replacements):
    tree = Digraph("rectree")
    tree.node("root", "")
    variations = []
    def dfs(ind, pos, P_id):
        if ind == len(name):
            L_id = f"{pos}"
            tree.node(L_id, pos, shape="box")
            tree.edge(P_id, L_id)
            variations.append(L_id)
            return

        for length in range(1, len(name) - ind + 1):
            substring = name[ind:ind + length]
            if substring in replacements:
                for replacement in replacements[substring]:
                    C_id = f"{pos + replacement}_{ind + length}"
                    tree.node(C_id, pos + replacement)
                    tree.edge(P_id, C_id)
                    dfs(ind + length, pos + replacement, C_id)

    dfs(0, "", "root")
    return tree,variations

# %%
def valid_list(word):
    vars = gen_tree(phonemizer(word, lang='fr'), replacements)[1]
    valid = []
    for e in vars:
        if phonemizer(e.lower(), lang='fr') == phonemizer(word, lang='fr'):
            valid.append(e+ " : " + phonemizer(e.lower(), lang='fr'))
    return valid

# %%
gen_tree(phonemizer("samantha",lang='fr'), replacements)[0]

# %%
valid_list("samantha")
# Out:
# ['SAMANTA : samɑ̃ta',
#  'SAMANTTA : samɑ̃ta',
#  'SAMENTA : samɑ̃ta',
#  'SAMENTTA : samɑ̃ta',
#  'SAMMANTA : samɑ̃ta',
#  'SAMMANTTA : samɑ̃ta',
#  'SAMMENTA : samɑ̃ta',
#  'SAMMENTTA : samɑ̃ta',
#  'SSAMANTA : samɑ̃ta',
#  'SSAMANTTA : samɑ̃ta',
#  'SSAMENTA : samɑ̃ta',
#  'SSAMENTTA : samɑ̃ta',
#  'SSAMMANTA : samɑ̃ta',
#  'SSAMMANTTA : samɑ̃ta',
#  'SSAMMENTA : samɑ̃ta',
#  'SSAMMENTTA : samɑ̃ta']

# %%
gen_tree(phonemizer("caroline",lang='fr'), replacements)[0]

# %%
valid_list("caroline")
# Out:
# ['KAROLINN : kaʁɔlin',
#  'KAROLYNN : kaʁɔlin',
#  'KAROLLINN : kaʁɔlin',
#  'KAROLLYNN : kaʁɔlin',
#  'CAROLINN : kaʁɔlin',
#  'CAROLYNN : kaʁɔlin',
#  'CAROLLINN : kaʁɔlin',
#  'CAROLLYNN : kaʁɔlin',
#  'QUAROLINN : kaʁɔlin',
#  'QUAROLYNN : kaʁɔlin',
#  'QUAROLLINN : kaʁɔlin',
#  'QUAROLLYNN : kaʁɔlin']

# %%
gen_tree(phonemizer("héloïse",lang='fr'), replacements)[0]

# %%
valid_list("héloïse")
# Out:
# ['ÉLLOYZ : elɔiz']

# %%
gen_tree(phonemizer("martin",lang='fr'), replacements)[0]

# %%
phonemizer("martin",lang='fr')
# Out:
# 'maʁtɛ̃'

# %%
valid_list("martin")
# Out:
# ['MARTIN : maʁtɛ̃',
#  'MARTAIN : maʁtɛ̃',
#  'MARTEIN : maʁtɛ̃',
#  'MARTTIN : maʁtɛ̃',
#  'MARTTAIN : maʁtɛ̃',
#  'MARTTEIN : maʁtɛ̃',
#  'MMARTIN : maʁtɛ̃',
#  'MMARTAIN : maʁtɛ̃',
#  'MMARTEIN : maʁtɛ̃',
#  'MMARTTIN : maʁtɛ̃',
#  'MMARTTAIN : maʁtɛ̃',
#  'MMARTTEIN : maʁtɛ̃']

# %%
gen_tree(phonemizer("clémence",lang='fr'), replacements)[0]

# %%
valid_list("clémence")
# Out:
# ['KLÉMANSS : klemɑ̃s',
#  'KLLÉMANSS : klemɑ̃s',
#  'KLLÉMENSS : klemɑ̃s',
#  'KLLÉMMANSS : klemɑ̃s',
#  'CLÉMANSS : klemɑ̃s',
#  'CLÉMENSS : klemɑ̃s',
#  'CLÉMMANSS : klemɑ̃s',
#  'CLÉMMENSS : klemɑ̃s',
#  'CLÊMANSS : klemɑ̃s',
#  'CLLÉMANSS : klemɑ̃s',
#  'CLLÉMENSS : klemɑ̃s',
#  'CLLÉMMANSS : klemɑ̃s',
#  'CLLÉMMENSS : klemɑ̃s']
