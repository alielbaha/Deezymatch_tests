# %%
import DeezyMatch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import DeezyMatch
#
# File c:\Users\asus\DeezyMatch\DeezyMatch\__init__.py:1
# ----> 1 from DeezyMatch.DeezyMatch import train
#       2 from DeezyMatch.DeezyMatch import finetune
#       3 from DeezyMatch.DeezyMatch import inference
#
# File c:\Users\asus\DeezyMatch\DeezyMatch\DeezyMatch.py:18
#      15 import shutil
#      16 import sys
# ---> 18 from .candidateRanker import candidate_ranker
#      19 from .candidateRanker import main as candidate_ranker_main
#      20 from .combineVecs import combine_vecs
#
# File c:\Users\asus\DeezyMatch\DeezyMatch\candidateRanker.py:11
#       9 from argparse import ArgumentParser
#      10 from collections import OrderedDict
# ---> 11 import faiss
#      12 import glob
#      13 import numpy as np
#
# ModuleNotFoundError: No module named 'faiss'

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Obtaining dependency information for torch>=1.5.0 from https://files.pythonhosted.org/packages/11/c5/2370d96b31eb1841c3a0883a492c15278a6718ccad61bb6a649c80d1d9eb/torch-2.6.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.6.0-cp311-cp311-win_amd64.whl.metadata (28 kB)
# ...
#   Obtaining dependency information for torchvision>=0.6.0 from https://files.pythonhosted.org/packages/88/53/4ad334b9b1d8dd99836869fec139cb74a27781298360b91b9506c53f1d10/torchvision-0.21.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached torchvision-0.21.0-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# ...
#   Obtaining dependency information for ipywidgets>=7.5.1 from https://files.pythonhosted.org/packages/22/2d/9c0b76f2f9cc0ebede1b9371b6f317243028ed60b90705863d493bae622e/ipywidgets-8.1.5-py3-none-any.whl.metadata
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# ...

# %%
from DeezyMatch import train
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from DeezyMatch import train
#
# File c:\Users\asus\DeezyMatch\DeezyMatch\__init__.py:1
# ----> 1 from DeezyMatch.DeezyMatch import train
#       2 from DeezyMatch.DeezyMatch import finetune
#       3 from DeezyMatch.DeezyMatch import inference
#
# File c:\Users\asus\DeezyMatch\DeezyMatch\DeezyMatch.py:18
#      15 import shutil
#      16 import sys
# ---> 18 from .candidateRanker import candidate_ranker
#      19 from .candidateRanker import main as candidate_ranker_main
#      20 from .combineVecs import combine_vecs
#
# File c:\Users\asus\DeezyMatch\DeezyMatch\candidateRanker.py:11
#       9 from argparse import ArgumentParser
#      10 from collections import OrderedDict
# ---> 11 import faiss
#      12 import glob
#      13 import numpy as np
#
# ModuleNotFoundError: No module named 'faiss'

# %%
# !pip install faiss-cpu
# Out:
# ...
#   Obtaining dependency information for faiss-cpu from https://files.pythonhosted.org/packages/2c/2d/d2a4171a9cca9a7c04cd9d6f9441a37f1e0558724b90bf7fc7db08553601/faiss_cpu-1.10.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached faiss_cpu-1.10.0-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# ...
# Using cached faiss_cpu-1.10.0-cp311-cp311-win_amd64.whl (13.7 MB)
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: C:\Python311\python.exe -m pip install --upgrade pip

# %%
import DeezyMatch
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import DeezyMatch
#
# File c:\Users\asus\DeezyMatch\DeezyMatch\__init__.py:1
# ----> 1 from DeezyMatch.DeezyMatch import train
#       2 from DeezyMatch.DeezyMatch import finetune
#       3 from DeezyMatch.DeezyMatch import inference
#
# File c:\Users\asus\DeezyMatch\DeezyMatch\DeezyMatch.py:18
#      15 import shutil
#      16 import sys
# ---> 18 from .candidateRanker import candidate_ranker
#      19 from .candidateRanker import main as candidate_ranker_main
#      20 from .combineVecs import combine_vecs
#
# File c:\Users\asus\DeezyMatch\DeezyMatch\candidateRanker.py:15
#      13 import numpy as np
#      14 import os
# ---> 15 import pandas as pd
#      16 import pickle
#      17 from sklearn.metrics.pairwise import cosine_similarity
#
# ...

# %%
# %pip install faiss-cpu --no-cache
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: C:\Python311\python.exe -m pip install --upgrade pip

# %%
# !pip list
# Out:
# Package                 Version
# [notice] A new release of pip is available: 23.1.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ----------------------- -----------
# absl-py                 2.1.0
# asttokens               3.0.0
# colorama                0.4.6
# comm                    0.2.2
# contourpy               1.3.1
# cycler                  0.12.1
# debugpy                 1.8.12
# decorator               5.1.1
# executing               2.2.0
# faiss-cpu               1.10.0
# filelock                3.17.0
# fonttools               4.55.8
# fsspec                  2025.2.0
# grpcio                  1.70.0
# ipykernel               6.29.5
# ipython                 8.32.0
# ipywidgets              8.1.5
# jedi                    0.19.2
# Jinja2                  3.1.5
# joblib                  1.4.2
# jupyter_client          8.6.3
# jupyter_core            5.7.2
# jupyterlab_widgets      3.0.13
# kiwisolver              1.4.8
# ...

# %%
# !pip install .
# Out:
# Processing c:\users\asus\deezymatch
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for DeezyMatch: filename=DeezyMatch-1.3.4-py3-none-any.whl size=49038 sha256=26f0e749ee0fa508a3a2da63b2bfa16c8f1d5b07705ef911749212bae17005c0
#   Stored in directory: C:\Users\asus\AppData\Local\Temp\pip-ephem-wheel-cache-ih1l6pgj\wheels\1a\51\90\f28c1136152705478debf6092b77d659c95e934bb4906adb9d
# Successfully built DeezyMatch
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import DeezyMatch
# Out:
# Matplotlib is building the font cache; this may take a moment.
# c:\Users\asus\DeezyMatch\DeezyMatch\rnn_networks.py:30: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
help(DeezyMatch)
# Out:
# Help on package DeezyMatch:
#
# NAME
#     DeezyMatch
#
# PACKAGE CONTENTS
#     DeezyMatch
#     candidateRanker
#     combineVecs
#     data_processing
#     rnn_networks
#     utils
#     utils_candidate_ranker
#
# FILE
#     c:\users\asus\deezymatch\deezymatch\__init__.py

# %%
from DeezyMatch import train as dm_train

dm_train(input_file_path="./inputs/input_dfm.yaml", 
         dataset_path="dataset/dataset-string-matching_train.txt", 
         model_name="test001")
# Out:
# c:\Users\asus\DeezyMatch\DeezyMatch\rnn_networks.py:30: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# 2025-02-03 01:50:34 Enigma-2 [INFO] read input file: ./inputs/input_dfm.yaml
# 2025-02-03 01:50:34 Enigma-2 [INFO] GPU was requested but not available.
# 2025-02-03 01:50:34 Enigma-2 [INFO] pytorch will use: cpu
# 2025-02-03 01:50:34 Enigma-2 [INFO] read CSV file: dataset/dataset-string-matching_train.txt
# 2025-02-03 01:50:34 Enigma-2 [INFO] number of labels, True: 2500 and False: 2500
# 2025-02-03 01:50:34 Enigma-2 [INFO] Splitting the Dataset
# 2025-02-03 01:50:34 Enigma-2 [INFO] finish splitting the Dataset. User time: 0.018851280212402344
# 2025-02-03 01:50:34 Enigma-2 [INFO] splits are as follow:
# split
# train    3500
# val       750
# test      750
# Name: count, dtype: int64
# ...

# %%
from DeezyMatch import plot_log

plot_log(path2log="./models/test001/log.txt", 
         output_name="t001")
# Out:
# output_name: t001
# Time: 173s
# output_name: t001
# Time / epoch: 43.250s
# ...
# Epoch: 1, Loss: 0.695
# Epoch: 1, macro F1: 0.399
# Epoch: 1, Acc: 0.504
# Epoch: 1, Prec/Recall: 0.502/0.923

# %%
#10 epochs
dm_train(input_file_path="./inputs/input_dfm.yaml", 
         dataset_path="dataset/dataset-string-matching_train.txt", 
         model_name="test002")
# Out:
# 2025-02-03 01:59:33 Enigma-2 [INFO] read input file: ./inputs/input_dfm.yaml
# 2025-02-03 01:59:33 Enigma-2 [INFO] GPU was requested but not available.
# 2025-02-03 01:59:33 Enigma-2 [INFO] pytorch will use: cpu
# 2025-02-03 01:59:33 Enigma-2 [INFO] read CSV file: dataset/dataset-string-matching_train.txt
# 2025-02-03 01:59:33 Enigma-2 [INFO] number of labels, True: 2500 and False: 2500
# 2025-02-03 01:59:33 Enigma-2 [INFO] Splitting the Dataset
# 2025-02-03 01:59:33 Enigma-2 [INFO] finish splitting the Dataset. User time: 0.006474018096923828
# 2025-02-03 01:59:33 Enigma-2 [INFO] splits are as follow:
# split
# train    3500
# val       750
# test      750
# Name: count, dtype: int64
# 2025-02-03 01:59:33 Enigma-2 [INFO] start creating a lookup table and convert characters to indices
# 2025-02-03 01:59:33 Enigma-2 [INFO] -- create vocabulary
# 2025-02-03 01:59:33 Enigma-2 [INFO] -- convert tokens to indices
# 2025-02-03 01:59:33 Enigma-2 [INFO] -- create a lookup table for tokens
# ...

# %%
plot_log(path2log="./models/test002/log.txt", 
         output_name="t002")
# Out:
# output_name: t002
# Time: 373s
# output_name: t002
# Time / epoch: 41.444s
# ...
# Epoch: 1, Loss: 0.693
# Epoch: 1, macro F1: 0.454
# Epoch: 1, Acc: 0.481
# Epoch: 1, Prec/Recall: 0.487/0.707

# %%
from DeezyMatch import finetune as dm_finetune

dm_finetune(input_file_path="./inputs/input_dfm.yaml", 
            dataset_path="dataset/dataset-string-matching_finetune.txt", 
            model_name="finetuned_test001",
            pretrained_model_path="./models/test001/test001.model", 
            pretrained_vocab_path="./models/test001/test001.vocab")
# Out:
# c:\Users\asus\DeezyMatch\DeezyMatch\rnn_networks.py:30: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# 2025-02-03 02:42:18 Enigma-2 [INFO] read input file: ./inputs/input_dfm.yaml
# 2025-02-03 02:42:18 Enigma-2 [INFO] GPU was requested but not available.
# 2025-02-03 02:42:18 Enigma-2 [INFO] pytorch will use: cpu
# 2025-02-03 02:42:18 Enigma-2 [INFO] read CSV file: dataset/dataset-string-matching_finetune.txt
# 2025-02-03 02:42:18 Enigma-2 [INFO] number of labels, True: 1250 and False: 1250
# 2025-02-03 02:42:18 Enigma-2 [INFO] Splitting the Dataset
# 2025-02-03 02:42:18 Enigma-2 [INFO] finish splitting the Dataset. User time: 0.014013528823852539
# 2025-02-03 02:42:18 Enigma-2 [INFO] splits are as follow:
# split
# train    1750
# test      376
# val       374
# Name: count, dtype: int64
# ...

# %%
from DeezyMatch import plot_log

# %%
plot_log(path2log="./models/finetuned_test001/log.txt", 
         output_name="t002")
# Out:
# output_name: t002
# Time: 19s
# output_name: t002
# Time / epoch: 2.111s
# ...
# Epoch: 1, Loss: 0.704
# Epoch: 1, macro F1: 0.417
# Epoch: 1, Acc: 0.427
# Epoch: 1, Prec/Recall: 0.403/0.297

# %%
#10 epochs
dm_train(input_file_path="./inputs/input_dfm.yaml", 
         dataset_path="dataset/dataset-string-matching_train.txt", 
         model_name="test002")

# %%
import pandas as pd

df = pd.read_csv("allCountries.txt", sep='\t', header=None)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_26776\3438214706.py:3: DtypeWarning: Columns (9,10,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("allCountries.txt", sep='\t', header=None)
#         0                             1                             2   \
# 0  2994701                     Roc Meler                     Roc Meler
# 1  3017832          Pic de les Abelletes          Pic de les Abelletes
# 2  3017833       Estany de les Abelletes       Estany de les Abelletes
# 3  3023203  Port Vieux de la Coume d’Ose  Port Vieux de la Coume d'Ose
# 4  3029315          Port de la Cabanette          Port de la Cabanette
#
#                                                   3         4        5  6   \
# 0                        Roc Mele,Roc Meler,Roc Mélé  42.58765  1.74180  T
# 1  Pic de la Font-Negre,Pic de la Font-Nègre,Pic ...  42.52535  1.73343  T
# 2  Estany de les Abelletes,Etang de Font-Negre,Ét...  42.52915  1.73362  H
# ...

# %%
len(df)
# Out:
# 13040485

# %%
df.head(50)

# %%
# !pip install jellyfish
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/212.1 kB ? eta -:--:--
#      ------------------------------------- 212.1/212.1 kB 12.6 MB/s eta 0:00:00
# ...

# %%
# !pip install pyxdameraulevenshtein
# Out:
# ...
#                                               0.0/62.6 kB ? eta -:--:--
#      ---------------------------------------- 62.6/62.6 kB 3.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build pyxdameraulevenshtein
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyxdameraulevenshtein (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [11 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-311\pyxdameraulevenshtein
#       copying pyxdameraulevenshtein\__init__.py -> build\lib.win-amd64-cpython-311\pyxdameraulevenshtein
# ...

# %%
# !pip install alphabet_detector
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for alphabet_detector: filename=alphabet_detector-0.0.7-py3-none-any.whl size=2474 sha256=0248ffd65fb72aa2d09d748a7ecaf2e1d926f2d67f2f2d34432bdea9df5a07eb
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\3f\07\5b\be33d78a45eb1aa1dc489103d02eff1a1c0ada85c45322616b
# Successfully built alphabet_detector
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
build_dataset_from_geonames(input='allCountries.txt', output='dataset-unfiltered.txt')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 build_dataset_from_geonames(input='allCountries.txt', output='dataset-unfiltered.txt')
#
# Cell In[14], line 56, in build_dataset_from_geonames(input, output)
#      55 def build_dataset_from_geonames(input='allCountries.txt', output='dataset-unfiltered.txt'):
# ---> 56     csv.field_size_limit(sys.maxsize)
#      57     lastname = None
#      58     lastname2 = None
#
# OverflowError: Python int too large to convert to C long
