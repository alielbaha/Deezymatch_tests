# %%
# !pip install torch transformers sentence-transformers
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 55.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 43.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 29.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
from sentence_transformers import SentenceTransformer, util

# %%
model = SentenceTransformer("shahrukhx01/paraphrase-mpnet-base-v2-fuzzy-matcher")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.71k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/595 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
entities = [
    "алекс ", #alex
    "Винсент", #vincent
    "джонатан", #jonathan
    "майкл", # michael
    "Роберт",
    "Бобби",
    "Саманта",
    "Элизабет"

]

# %%
entity_embeddings = model.encode(entities, convert_to_tensor=True)

# %%
queries = ["vincent"]

for query in queries:
    query_embedding = model.encode(query, convert_to_tensor=True)
    similarities = util.pytorch_cos_sim(query_embedding, entity_embeddings)
    print(f"query: {query} --> sim score: {similarities}")
    best_match_idx = similarities.argmax().item()
    best_match = entities[best_match_idx]
    similarity_score = similarities[0][best_match_idx].item()

    print(f"query: {query} --> best Match: {best_match} (score: {similarity_score:.4f})")
# Out:
# query: vincent --> sim score: tensor([[0.0767, 0.1196, 0.0743, 0.1017, 0.0539, 0.0465, 0.0356, 0.0733]])
# query: vincent --> best Match: Винсент (score: 0.1196)

# %%
entities2 = [
    "алекс ", #alex
    "Винсент", #vincent
    "джонатан", #jonathan
    "майкл", # michael
    "Роберт",
    "Бобби",
    "Саманта",
    "Элизабет"

]

entity_embeddings2 = model.encode(entities2, convert_to_tensor=True)

queries2 = ["vincent", "michael", "samantha"]

for query in queries2:
    query_embedding = model.encode(query, convert_to_tensor=True)
    similarities = util.pytorch_cos_sim(query_embedding, entity_embeddings2)
    print(f"query: {query} --> sim score: {similarities}")
    best_match_idx = similarities.argmax().item()
    best_match = entities2[best_match_idx]
    similarity_score = similarities[0][best_match_idx].item()

    print(f"query: {query} --> best match: {best_match} (score: {similarity_score:.4f})")
# Out:
# query: vincent --> sim score: tensor([[0.0767, 0.1196, 0.0743, 0.1017, 0.0539, 0.0465, 0.0356, 0.0733]])
# query: vincent --> best match: Винсент (score: 0.1196)
# query: michael --> sim score: tensor([[0.0822, 0.0235, 0.0869, 0.1052, 0.0385, 0.0116, 0.1044, 0.0057]])
# query: michael --> best match: майкл (score: 0.1052)
# query: samantha --> sim score: tensor([[ 0.0792, -0.0312,  0.0297,  0.0547,  0.0381, -0.0095,  0.1905, -0.0057]])
# query: samantha --> best match: Саманта (score: 0.1905)

# %%
entities2 = [
    "  سامنثا  ", #samantha
    "بوبي", #bobby
    "إليزابيث", #elizabeth
    "روبرت", # robert
    "Роберт",
    "боби",
    "Саманта",
    "Элизабет"

]

entity_embeddings2 = model.encode(entities2, convert_to_tensor=True)

queries2 = ["samantha", "elizabeth", "robert","boby"]

for query in queries2:
    query_embedding = model.encode(query, convert_to_tensor=True)
    similarities = util.pytorch_cos_sim(query_embedding, entity_embeddings2)
    print(f"query: {query} --> sim score: {similarities}")
    best_match_idx = similarities.argmax().item()
    best_match = entities2[best_match_idx]
    similarity_score = similarities[0][best_match_idx].item()

    print(f"query: {query} --> best match: {best_match} (score: {similarity_score:.4f})")
# Out:
# query: samantha --> sim score: tensor([[ 0.2053,  0.0585,  0.1216,  0.1079,  0.0381, -0.0379,  0.1905, -0.0057]])
# query: samantha --> best match:   سامنثا   (score: 0.2053)
# query: elizabeth --> sim score: tensor([[0.0773, 0.0804, 0.1365, 0.0688, 0.0300, 0.0158, 0.0736, 0.0963]])
# query: elizabeth --> best match: إليزابيث (score: 0.1365)
# query: robert --> sim score: tensor([[0.0565, 0.0954, 0.1586, 0.2282, 0.2089, 0.1253, 0.0789, 0.1122]])
# query: robert --> best match: روبرت (score: 0.2282)
# query: boby --> sim score: tensor([[0.0065, 0.1769, 0.0887, 0.1174, 0.1356, 0.2369, 0.0525, 0.0645]])
# query: boby --> best match: боби (score: 0.2369)

# %%
queries = ["vincent"]

for query in queries:
    query_embedding = model.encode(query, convert_to_tensor=True)
    similarities = util.pytorch_cos_sim(query_embedding, entity_embeddings)
    print(f"query: {query} --> sim score: {similarities}")
    best_match_idx = similarities.argmax().item()
    best_match = entities[best_match_idx]
    similarity_score = similarities[0][best_match_idx].item()

    print(f"query: {query} --> best Match: {best_match} (score: {similarity_score:.4f})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d2cc93d82da> in <cell line: 0>()
#       2
#       3 for query in queries:
# ----> 4     query_embedding = model.encode(query, convert_to_tensor=True)
#       5     similarities = util.pytorch_cos_sim(query_embedding, entity_embeddings)
#       6     print(f"query: {query} --> sim score: {similarities}")
#
# NameError: name 'model' is not defined

# %%
import pandas as pd

def gen(name):
    pass

df = pd.read_csv("names.csv")

first_column = df.columns[0]


df["variations"] = df[first_column].apply(lambda name: ", ".join(gen_variations(name)))


df.to_csv("prenoms_variations.csv", index=False)

print("saved")
# Out:
# saved

# %%
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer, util
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.71k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/595 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Johnathan: 0.9818
# Jonathon: 0.9765
# Nathan: 0.8637
# Johnny: 0.8179
# Jon: 0.6677

# %%
def rank_name_variations(name, variations):

    model = SentenceTransformer('shahrukhx01/paraphrase-mpnet-base-v2-fuzzy-matcher')

    name_tokenized = " ".join(name)
    variations_tokenized = [" ".join(var) for var in variations]

    name_embedding = model.encode(name_tokenized)
    variation_embeddings = model.encode(variations_tokenized)

    scores = [util.cos_sim(name_embedding, var_emb).item() for var_emb in variation_embeddings]

    ranked_variations = sorted(zip(variations, scores), key=lambda x: x[1], reverse=True)

    return ranked_variations

# %%
name = "Jonathan"
variations = ["Johnathan", "Jon", "Johnny", "Nathan", "Jonathon"]
ranked_list = rank_name_variations(name, variations)

print('query :', name)
print('candidates:')
for var, score in ranked_list:
    print(f"{var}: {score:.4f}")
# Out:
# query : Jonathan
# candidates:
# Johnathan: 0.9818
# Jonathon: 0.9765
# Nathan: 0.8637
# Johnny: 0.8179
# Jon: 0.6677

# %%
df = pd.read_csv("names_.csv")

first_column = df.columns[0]
second_column = df.columns[1]

# %%
for name in df['variations']:
    print(name)
# Out:
# Mike, Mikey, Michel, Micheal, Mikael, Michal
# Liz, Lizzy, Eliza, Beth, Eli, Liza
# John, Jon, Jonny, Johnny, Jhonathan, Jona
# Kate, Katie, Kathy, Kath, Kathryn, Katherin
# Will, Willy, Bill, Billy, Wiliam, Willam
# Chris, Topher, Kristopher, Cristopher, Chrissy
# Alex, Xander, Lex, Aleksander, Alejandro
# Jen, Jenny, Jeni, Jenna, Jenn
# Rob, Bob, Bobby, Robbie, Roberto
# Matt, Mat, Mathew, Matheu, Matty
# Jeannot, Jeanno, Jehan, Jeanot
# Franck, Francis, Francois, Françoys
# Lotte, Charly, Charlot, Charlott
# Guilhem, William, Gillaume, Gui
# Théophile, Theo, Teo
# Soph, Sophia, Sophy, Sofie
# Nico, Nicolas, Nick, Nikola
# Elo, Elodia, Elodi, Lodie
# Ben, Benoist, Benoit, Benny
# Celin, Celina, Célinette, Lina
# Gio, Vanni, Gianni, Giovanny
# Franci, Cesca, Fran, Franceska
# Alessio, Sandro, Alex, Alessandrino
# Giuli, Julie, Julietta, Giulietta
# Teo, Mattia, Mat, Matt
# Enzo, Lory, Renzo, Lorenzino
# Beppe, Peppe, Peppino, Giusi
# Angy, Angelina, Angel, Angie
# Ste, Stef, Stefanuccio, Stevy
# Robi, Robertino, Berto, Robby

# %%
df
# Out:
#            Name                                      Variations
# 0       Michael    Mike, Mikey, Michel, Micheal, Mikael, Michal
# 1     Elizabeth              Liz, Lizzy, Eliza, Beth, Eli, Liza
# 2      Jonathan       John, Jon, Jonny, Johnny, Jhonathan, Jona
# 3     Katherine     Kate, Katie, Kathy, Kath, Kathryn, Katherin
# 4       William        Will, Willy, Bill, Billy, Wiliam, Willam
# 5   Christopher  Chris, Topher, Kristopher, Cristopher, Chrissy
# 6     Alexander        Alex, Xander, Lex, Aleksander, Alejandro
# 7      Jennifer                   Jen, Jenny, Jeni, Jenna, Jenn
# 8        Robert                Rob, Bob, Bobby, Robbie, Roberto
# 9       Matthew                Matt, Mat, Mathew, Matheu, Matty
# 10         Jean                  Jeannot, Jeanno, Jehan, Jeanot
# 11     François             Franck, Francis, Francois, Françoys
# 12    Charlotte                Lotte, Charly, Charlot, Charlott
# 13    Guillaume                 Guilhem, William, Gillaume, Gui
# 14         Théo                            Théophile, Theo, Teo
# 15       Sophie                      Soph, Sophia, Sophy, Sofie
# 16      Nicolas                     Nico, Nicolas, Nick, Nikola
# 17       Élodie                       Elo, Elodia, Elodi, Lodie
# 18       Benoît                     Ben, Benoist, Benoit, Benny
# 19       Céline                  Celin, Celina, Célinette, Lina
# 20     Giovanni                    Gio, Vanni, Gianni, Giovanny
# 21    Francesca                  Franci, Cesca, Fran, Franceska
# 22   Alessandro             Alessio, Sandro, Alex, Alessandrino
# 23       Giulia               Giuli, Julie, Julietta, Giulietta
# 24       Matteo                          Teo, Mattia, Mat, Matt
# 25      Lorenzo                    Enzo, Lory, Renzo, Lorenzino
# 26     Giuseppe                    Beppe, Peppe, Peppino, Giusi
# 27       Angela                    Angy, Angelina, Angel, Angie
# 28      Stefano                   Ste, Stef, Stefanuccio, Stevy
# 29      Roberto                   Robi, Robertino, Berto, Robby

# %%
df['variations'] = df['variations'].apply(lambda x: x.split(',') if isinstance(x, str) else [])

# %%
# Out:
#            Name                                         Variations
# 0       Michael  [Mike,  Mikey,  Michel,  Micheal,  Mikael,  Mi...
# 1     Elizabeth          [Liz,  Lizzy,  Eliza,  Beth,  Eli,  Liza]
# 2      Jonathan   [John,  Jon,  Jonny,  Johnny,  Jhonathan,  Jona]
# 3     Katherine  [Kate,  Katie,  Kathy,  Kath,  Kathryn,  Kathe...
# 4       William    [Will,  Willy,  Bill,  Billy,  Wiliam,  Willam]
# 5   Christopher  [Chris,  Topher,  Kristopher,  Cristopher,  Ch...
# 6     Alexander     [Alex,  Xander,  Lex,  Aleksander,  Alejandro]
# 7      Jennifer                [Jen,  Jenny,  Jeni,  Jenna,  Jenn]
# 8        Robert             [Rob,  Bob,  Bobby,  Robbie,  Roberto]
# 9       Matthew             [Matt,  Mat,  Mathew,  Matheu,  Matty]
# 10         Jean                [Jeannot,  Jeanno,  Jehan,  Jeanot]
# 11     François           [Franck,  Francis,  Francois,  Françoys]
# 12    Charlotte              [Lotte,  Charly,  Charlot,  Charlott]
# 13    Guillaume               [Guilhem,  William,  Gillaume,  Gui]
# 14         Théo                           [Théophile,  Theo,  Teo]
# 15       Sophie                    [Soph,  Sophia,  Sophy,  Sofie]
# 16      Nicolas                   [Nico,  Nicolas,  Nick,  Nikola]
# 17       Élodie                     [Elo,  Elodia,  Elodi,  Lodie]
# 18       Benoît                   [Ben,  Benoist,  Benoit,  Benny]
# 19       Céline                [Celin,  Celina,  Célinette,  Lina]
# 20     Giovanni                  [Gio,  Vanni,  Gianni,  Giovanny]
# 21    Francesca                [Franci,  Cesca,  Fran,  Franceska]
# 22   Alessandro           [Alessio,  Sandro,  Alex,  Alessandrino]
# 23       Giulia             [Giuli,  Julie,  Julietta,  Giulietta]
# 24       Matteo                        [Teo,  Mattia,  Mat,  Matt]
# 25      Lorenzo                  [Enzo,  Lory,  Renzo,  Lorenzino]
# 26     Giuseppe                  [Beppe,  Peppe,  Peppino,  Giusi]
# 27       Angela                  [Angy,  Angelina,  Angel,  Angie]
# 28      Stefano                 [Ste,  Stef,  Stefanuccio,  Stevy]
# 29      Roberto                 [Robi,  Robertino,  Berto,  Robby]

# %%
def ranked_list(file):


    df = pd.read_csv(file)

    df["variations"] = df["Fr_names"].str.extract(r'\"(.*?)\"')

    df["Fr_names"] = df["Fr_names"].str.replace(r',"[^"]*"', '', regex=True)


    df['variations'] = df['variations'].apply(lambda x: x.split(',') if isinstance(x, str) else [])

    df.head()
    for i in range(len(df)):
        ranked_list = rank_name_variations(df['Fr_names'][i], df['variations'][i])
        print('\n')
        print('query :', df['Fr_names'][i])
        print('candidates:')
        for var, score in ranked_list:
            print(f"{var}: {score:.4f}")

# %%
df = pd.read_csv("rejected_names.csv")

df['variations'] = df['variations'].apply(lambda x: x.split(',') if isinstance(x, str) else [])

# %%
df = pd.read_csv("kept_variations.csv")
#
df["variations"] = df["Fr_names"].str.extract(r'\"(.*?)\"')

df["Fr_names"] = df["Fr_names"].str.replace(r',"[^"]*"', '', regex=True)

# %%
df
# Out:
#     Fr_names                                         variations
# 0    absolon  ABSCOLOM, ABSAULON, ABSAULAUN, ABSSOLAUN, ABSS...
# 1    achille                   ASHILLE, ACHILE, ACHILLE, ASHILE
# 2      adèle  ADELÊ, ADELEU, ADÈLÈ, ADÈLÊ, ADEULE, ADÈLE, AD...
# 3    adeline  ADÈLYNE, ADÊLINEU, ADEULINÈ, ADELYNÉ, ADELYNÈ,...
# 4    adolphe  ADAULPHÉ, ADOLFE, ADOLPHE, ADOLVE, ADOLFÈ, ADA...
# 5     amaury              AMAURI, AMAURY, AMORY, ANAURI, ANAURY
# 6      ambre  AMBREU, ONBRE, ANBRE, AMBRÊ, AMBRÉ, ANBREU, AN...
# 7   ambroise  AMBROYSÊ, ANBROYSÉ, ANBROYSÈ, ANBROISÉ, AMBROI...
# 8     amédée  AMEUDEU, AMÊDEU, ANÉDEU, AMÈDE, AMÊDÉ, AMÊDE, ...
# 9     amélie  AMÈLIE, AMELIÉ, AMEULIÈ, AMÊLIE, AMÉLYEU, AMÊL...
# 10      anne  ANNEU, ANNÈ, ANNE, ANMEU, ANNÉ, ANNÊ, ONNEU, O...
# 11   arianne  ARIONNEU, ARIANNEU, ARIANMEU, ARIANME, ARIANMÈ...
# 12   arienne  ARIENMÊ, ARYENMEU, ARYEMNE, ARIENNÊ, ARIENNÉ, ...
# 13   arlette  ARLÈTÊ, ARLÈPTEU, ARLEPE, ARLÊPTEU, ARLÊTÉ, AR...
# 14    armand  ARMONP, ARMONT, ARNOND, ARNAND, ARNAMD, ARMAMX...
# 15   josette  JOSÈTÈ, JOSEPTÉ, JOZETE, JOSEPÊ, JOSETÈ, JOSÈT...
# 16   josiane  JOZYANEU, JAUSIANE, JAUSYANEU, JOSIAMEU, JOSIA...
# 17  jourdain             GOURDAIN, GOURDAIM, JOURDAIN, JOURDAIM
# 18     jules  JULÉX, JULÊX, JULÈX, JULÉD, JULÉS, JULEUS, JUL...
# 19   juliane  JULYANÉ, JULYAME, JULIANEU, JULIAMÊ, JULYANÊ, ...
# 20     julie  JULIEU, JULYEU, JULIÉ, JULIÈ, JULYÈ, JULIÊ, JU...
# 21    julien  JULYEUM, JULYÈN, JULIÉN, JULYEN, JULIÈM, JULYE...
# 22  julienne  JULIEMMÉ, JULIENNÈ, JULIEMNEU, JULIENME, JULIE...
# 23  juliette  JULIEUPÊ, JULIÊTE, JULYÉTEU, JULIEPÈ, JULIÈPTE...
# 24     juste  JUSCPTÉ, JUSPEU, JUSPTEU, JUSTÊ, JUSPTÉ, JUSSP...

# %%
ranked_list('kept_variations1.csv')
# Out:
# query : absolon
# candidates:
#  ABSOLON: 1.0000
#  ABSSOLON: 0.9890
#  ABSAULON: 0.9552
#  ABSSAULON: 0.9542
#  ABSSOLAUN: 0.9503
#  ABSOLAUN: 0.9485
#  ABSSOLOM: 0.9412
#  ABSOLOM: 0.9350
#  ABSCOLON: 0.9163
#  ABSSAULOM: 0.9117
#  ABSCOLAUN: 0.9099
#  ABSAULOM: 0.9089
#  ABSCAULON: 0.9014
#  ABSAULAUN: 0.8947
#  ABSSOLAUM: 0.8887
#  ABSOLAUM: 0.8852
#  ABSCAULOM: 0.8661
# ABSCOLOM: 0.8659
#  ABSCOLAUM: 0.8505
#
#
# query : achille
# candidates:
#  ACHILLE: 1.0000
#  ACHILE: 0.9853
# ASHILLE: 0.8142
#  ASHILE: 0.8119
#
#
# query : adèle
# candidates:
# ADELÊ: 1.0000
#  ADÈLÈ: 1.0000
#  ADÈLÊ: 1.0000
#  ADÈLE: 1.0000
#  ADELÉ: 1.0000
#  ADELÈ: 1.0000
#  ADÉLÊ: 1.0000
#  ADÊLÉ: 1.0000
#  ADÉLE: 1.0000
#  ADÉLÈ: 1.0000
#  ADELE: 1.0000
#  ADÉLÉ: 1.0000
#  ADÈLÉ: 1.0000
#  ADÊLE: 1.0000
#  ADÊLÊ: 1.0000
#  ADÊLÈ: 1.0000
#  ADEULE: 0.9229
#  ADELEU: 0.9132
#  ADÉLEU: 0.9132
#  ADÈLEU: 0.9132
#  ADÊLEU: 0.9132
#  ADEULEU: 0.8993
#
#
# query : adeline
# candidates:
#  ADÊLINÈ: 1.0000
#  ADÈLINÉ: 1.0000
#  ADÉLINE: 1.0000
#  ADÉLINÊ: 1.0000
#  ADÊLINE: 1.0000
#  ADELINÉ: 1.0000
#  ADÊLINÊ: 1.0000
#  ADELINÈ: 1.0000
#  ADÈLINÈ: 1.0000
#  ADELINÊ: 1.0000
#  ADÉLINÈ: 1.0000
#  ADÉLINÉ: 1.0000
#  ADÈLINE: 1.0000
#  ADELINE: 1.0000
#  ADÈLINÊ: 1.0000
#  ADÊLINÉ: 1.0000
#  ADEULINÈ: 0.9617
#  ADEULINÊ: 0.9617
#  ADEULINÉ: 0.9617
#  ADEULINE: 0.9617
#  ADÊLINEU: 0.9437
#  ADÉLINEU: 0.9437
#  ADÈLINEU: 0.9437
#  ADELINEU: 0.9437
#  ADEULYNÊ: 0.9376
#  ADEULYNE: 0.9376
#  ADEULYNÉ: 0.9376
#  ADEULYNÈ: 0.9376
#  ADEULINEU: 0.9229
# ADÈLYNE: 0.9206
#  ADELYNÉ: 0.9206
#  ADELYNÈ: 0.9206
#  ADELYNÊ: 0.9206
#  ADÉLYNE: 0.9206
#  ADÊLYNE: 0.9206
#  ADELYNE: 0.9206
#  ADEULIME: 0.9177
#  ADEULIMÉ: 0.9177
#  ADEULIMÈ: 0.9177
#  ADEULIMÊ: 0.9177
#  ADÈLIME: 0.9114
#  ADELIME: 0.9114
#  ADÊLIME: 0.9114
#  ADELIMÉ: 0.9114
#  ADELIMÊ: 0.9114
#  ADÉLIME: 0.9114
#  ADELIMÈ: 0.9114
#  ADEULYNEU: 0.9071
#  ADÉLYNEU: 0.9028
#  ADÈLYNEU: 0.9028
#  ADELYNEU: 0.9028
#  ADÊLYNEU: 0.9028
#  ADEULYME: 0.8859
#  ADÊLIMEU: 0.8834
#  ADÉLIMEU: 0.8834
#  ADELIMEU: 0.8834
#  ADÈLIMEU: 0.8834
#  ADEULIMEU: 0.8769
#  ADEULYMEU: 0.8484
#  ADELYMEU: 0.8286
#  ADELYME: 0.8154
#
#
# query : adolphe
# candidates:
#  ADOLPHE: 1.0000
#  ADOLPHÊ: 1.0000
#  ADOLPHÉ: 1.0000
#  ADOLPHÈ: 1.0000
# ADAULPHÉ: 0.9244
#  ADAULPHÊ: 0.9244
#  ADAULPHÈ: 0.9244
#  ADAULPHE: 0.9244
#  ADOLPHEU: 0.9128
#  ADAULPHEU: 0.8505
#  ADOLFE: 0.8198
#  ADOLFÈ: 0.8198
#  ADOLFÉ: 0.8198
#  ADOLFÊ: 0.8198
#  ADOLVE: 0.7883
#  ADOLVÊ: 0.7883
#  ADOLVÉ: 0.7883
#  ADOLVÈ: 0.7883
#  ADOLFEU: 0.7527
#  ADOLVEU: 0.7332
#
#
# query : amaury
# candidates:
#  AMAURY: 1.0000
# AMAURI: 0.9224
#  AMORY: 0.8379
#  ANAURY: 0.8295
#  ANAURI: 0.7440
#
#
# query : ambre
# candidates:
#  AMBRÊ: 1.0000
#  AMBRÉ: 1.0000
#  AMBRÈ: 1.0000
#  AMBRE: 1.0000
# AMBREU: 0.8974
#  ANBRE: 0.8145
#  ANBRÈ: 0.8145
#  ANBRÉ: 0.8145
#  ANBRÊ: 0.8145
#  ONBRE: 0.8026
#  ANBREU: 0.7541
#
#
# query : ambroise
# candidates:
#  AMBROISE: 1.0000
#  AMBROISÈ: 1.0000
#  AMBROISÊ: 1.0000
#  AMBROISÉ: 1.0000
#  AMBROISEU: 0.9576
# AMBROYSÊ: 0.9440
#  AMBROYSÈ: 0.9440
#  AMBROYSE: 0.9440
#  AMBROYSÉ: 0.9440
#  AMBROYSEU: 0.9426
#  ANBROISÉ: 0.9130
#  ANBROISÊ: 0.9130
#  ANBROISÈ: 0.9130
#  ANBROISE: 0.9130
#  AMBROIZÉ: 0.9031
#  AMBROIZE: 0.9031
#  AMBROIZÈ: 0.9031
#  AMBROIZÊ: 0.9031
#  ONBROISÈ: 0.8799
#  ONBROISE: 0.8799
#  ONBROISÉ: 0.8799
#  ONBROISÊ: 0.8799
#  AMBROIZEU: 0.8747
#  ANBROISEU: 0.8685
#  ANBROYSÉ: 0.8658
#  ANBROYSÈ: 0.8658
#  ANBROYSÊ: 0.8658
#  ANBROYSE: 0.8658
#  ANBROYSEU: 0.8589
#  AMBROYZEU: 0.8585
#  ONBROYSE: 0.8439
#  ONBROISEU: 0.8347
#  AMBROYZÊ: 0.8284
#  AMBROYZE: 0.8284
#  AMBROYZÉ: 0.8284
#  AMBROYZÈ: 0.8284
#  ONBROIZE: 0.8163
#  ANBROIZE: 0.8073
#  ANBROIZÈ: 0.8073
#  ANBROIZÊ: 0.8073
#  ANBROIZÉ: 0.8073
#  ANBROIZEU: 0.7756
#  ANBROYZE: 0.7314
#
#
# query : amédée
# candidates:
#  AMÈDE: 0.9924
#  AMÊDÉ: 0.9924
#  AMÊDE: 0.9924
#  AMEDÉ: 0.9924
#  AMEDE: 0.9924
#  AMÉDE: 0.9924
#  AMÉDÉ: 0.9924
#  AMÉDÈ: 0.9924
#  AMÉDÊ: 0.9924
#  AMÈDÉ: 0.9924
#  AMEUDE: 0.9242
#  AMEUDÉ: 0.9242
# AMEUDEU: 0.9202
#  AMÊDEU: 0.9117
#  AMÈDEU: 0.9117
#  AMEDEU: 0.9117
#  AMÉDEU: 0.9117
#  ANÉDÉ: 0.8410
#  ANÉDE: 0.8410
#  ANÉDEU: 0.7492
#
#
# query : amélie
# candidates:
#  AMÉLIÊ: 1.0000
#  AMÊLIÉ: 1.0000
#  AMELIE: 1.0000
#  AMELIÊ: 1.0000
# AMÈLIE: 1.0000
#  AMELIÉ: 1.0000
#  AMÊLIE: 1.0000
#  AMÊLIÈ: 1.0000
#  AMÈLIÈ: 1.0000
#  AMELIÈ: 1.0000
#  AMÉLIÉ: 1.0000
#  AMÉLIÈ: 1.0000
#  AMÊLIÊ: 1.0000
#  AMÈLIÉ: 1.0000
#  AMÈLIÊ: 1.0000
#  AMÉLIE: 1.0000
#  AMEULIÈ: 0.9555
#  AMEULIÉ: 0.9555
#  AMEULIÊ: 0.9555
#  AMEULIE: 0.9555
#  AMELIEU: 0.9365
#  AMÈLIEU: 0.9365
#  AMÉLIEU: 0.9365
#  AMÊLIEU: 0.9365
#  AMEULYE: 0.9183
#  AMEULIEU: 0.9120
#  AMELYE: 0.9076
#  AMÉLYÉ: 0.9076
#  AMÉLYÈ: 0.9076
#  AMÈLYE: 0.9076
#  AMÉLYÊ: 0.9076
#  AMÉLYE: 0.9076
#  AMÊLYE: 0.9076
#  AMÉLYEU: 0.8825
#  AMÈLYEU: 0.8825
#  AMÊLYEU: 0.8825
#  AMELYEU: 0.8825
#  ANÉLIÉ: 0.8649
#  ANÈLIE: 0.8649
#  ANÊLIE: 0.8649
#  ANÉLIE: 0.8649
#  ANÉLIÊ: 0.8649
#  ANELIE: 0.8649
#  ANÉLIÈ: 0.8649
#  ANEULIE: 0.7984
#  ANÉLYE: 0.7975
#  ANELIEU: 0.7894
#  ANÈLIEU: 0.7894
#  ANÊLIEU: 0.7894
#  ANÉLIEU: 0.7894
#  ANÉLYEU: 0.7342
#
#
# query : anne
# candidates:
#  ANNÈ: 1.0000
#  ANNE: 1.0000
#  ANNÉ: 1.0000
#  ANNÊ: 1.0000
#  ONNE: 0.8932
# ANNEU: 0.8709
#  AMNE: 0.8479
#  ANME: 0.8249
#  ONNEU: 0.7814
#  AMNEU: 0.7734
#  ANMEU: 0.7398
#
#
# query : arianne
# candidates:
#  ARIANNE: 1.0000
#  ARIANNÉ: 1.0000
#  ARIANNÈ: 1.0000
#  ARIANNÊ: 1.0000
#  ARIONNÉ: 0.9664
#  ARIONNÈ: 0.9664
#  ARIONNE: 0.9664
#  ARIONNÊ: 0.9664
#  ARIANNEU: 0.9446
#  ARIANMÈ: 0.9331
#  ARIANMÉ: 0.9331
#  ARIANMÊ: 0.9331
#  ARIANME: 0.9331
#  ARIAMNÈ: 0.9325
#  ARIAMNÊ: 0.9325
#  ARIAMNE: 0.9325
#  ARIAMNÉ: 0.9325
#  ARIONME: 0.9217
#  ARIAMNEU: 0.9020
# ARIONNEU: 0.9014
#  ARYONNE: 0.8955
#  ARYANNÉ: 0.8936
#  ARYANNÊ: 0.8936
#  ARYANNE: 0.8936
#  ARYANNÈ: 0.8936
#  ARYANNEU: 0.8914
#  ARIANMEU: 0.8858
#  ARYONNEU: 0.8632
#  ARIONMEU: 0.8483
#  ARYAMNEU: 0.8460
#  ARYANMEU: 0.8420
#  ARIAMMEU: 0.8406
#  ARYANME: 0.8370
#  ARIAMME: 0.8320
#  ARYAMNE: 0.8182
#
#
# query : arienne
# candidates:
#  ARIENNÊ: 1.0000
#  ARIENNÉ: 1.0000
#  ARIENNÈ: 1.0000
#  ARIENNE: 1.0000
#  ARIENNEU: 0.9504
#  ARYENNÉ: 0.9277
#  ARYENNÈ: 0.9277
#  ARYENNE: 0.9277
#  ARYENNÊ: 0.9277
#  ARYENNEU: 0.9179
#  ARIEMNEU: 0.9127
#  ARIEMNÊ: 0.9121
#  ARIEMNÉ: 0.9121
#  ARIEMNÈ: 0.9121
#  ARIEMNE: 0.9121
# ARIENMÊ: 0.9098
#  ARIENMÉ: 0.9098
#  ARIENMÈ: 0.9098
#  ARIENME: 0.9098
#  ARIENMEU: 0.8866
#  ARYEMNEU: 0.8687
#  ARYENME: 0.8587
#  ARYENMEU: 0.8577
#  ARYEMNE: 0.8492
#  ARIEMMEU: 0.8365
#  ARIEMME: 0.8063
#
#
# query : arlette
# candidates:
# ARLÈTÊ: 0.9725
#  ARLÊTÉ: 0.9725
#  ARLETÈ: 0.9725
#  ARLÊTÊ: 0.9725
#  ARLETÊ: 0.9725
#  ARLÉTÈ: 0.9725
#  ARLÉTÊ: 0.9725
#  ARLÈTÈ: 0.9725
#  ARLÊTE: 0.9725
#  ARLÊTÈ: 0.9725
#  ARLÉTE: 0.9725
#  ARLÉTÉ: 0.9725
#  ARLÈTÉ: 0.9725
#  ARLETE: 0.9725
#  ARLETÉ: 0.9725
#  ARLÈTE: 0.9725
#  ARLÊPTE: 0.9094
#  ARLÉPTE: 0.9094
#  ARLÈPTE: 0.9094
#  ARLEPTÉ: 0.9094
#  ARLEPTÊ: 0.9094
#  ARLEPTÈ: 0.9094
#  ARLEPTE: 0.9094
#  ARLÊTEU: 0.8578
#  ARLÈTEU: 0.8578
#  ARLÉTEU: 0.8578
#  ARLETEU: 0.8578
#  ARLEUTÊ: 0.8571
#  ARLEUTÉ: 0.8571
#  ARLEUTÈ: 0.8571
#  ARLEUTE: 0.8571
#  ARLEUPTÊ: 0.8454
#  ARLEUPTÈ: 0.8454
#  ARLEUPTÉ: 0.8454
#  ARLEUPTE: 0.8454
#  ARLÈPTEU: 0.8437
#  ARLÊPTEU: 0.8437
#  ARLÉPTEU: 0.8437
#  ARLEPTEU: 0.8437
#  ARLEUTEU: 0.8345
#  ARLEPE: 0.7922
#  ARLEPÊ: 0.7922
#  ARLEPÉ: 0.7922
#  ARLEPÈ: 0.7922
#  ARLÊPE: 0.7922
#  ARLÉPE: 0.7922
#  ARLÈPE: 0.7922
#  ARLEUPTEU: 0.7896
#  ARLEUPE: 0.7585
#  ARLEPEU: 0.7441
#  ARLEUPEU: 0.7113
#
#
# query : armand
# candidates:
#  ARMAND: 1.0000
#  ARNAMD: 0.9773
#  ARMOND: 0.9233
#  ARMAMD: 0.9189
#  ARMANS: 0.8932
#  ARNAND: 0.8869
#  ARMANT: 0.8807
#  ARMANP: 0.8666
#  ARMONS: 0.8373
#  ARMAMT: 0.8299
#  ARMANX: 0.8278
#  ARMONT: 0.8269
#  ARNOND: 0.8204
# ARMONP: 0.8185
#  ARMONX: 0.8068
#  ARMAMS: 0.8030
#  ARMAMP: 0.7999
#  ARMAMX: 0.7689
#  ARNANT: 0.7675
#  ARNANS: 0.7435
#  ARNANP: 0.7169
#  ARNANX: 0.7027
#
#
# query : josette
# candidates:
#  JOSETÈ: 0.9655
#  JOSETÉ: 0.9655
#  JOSÉTÈ: 0.9655
#  JOSÊTÊ: 0.9655
#  JOSÉTÉ: 0.9655
#  JOSETÊ: 0.9655
#  JOSÈTÉ: 0.9655
#  JOSÈTE: 0.9655
#  JOSÊTÈ: 0.9655
#  JOSÊTÉ: 0.9655
# JOSÈTÈ: 0.9655
#  JOSÉTÊ: 0.9655
#  JOSÈTÊ: 0.9655
#  JOSÊTE: 0.9655
#  JOSETE: 0.9655
#  JOSÉTE: 0.9655
#  JOSEPTÊ: 0.9257
#  JOSÊPTE: 0.9257
#  JOSÉPTE: 0.9257
#  JOSÈPTE: 0.9257
#  JOSEPTE: 0.9257
#  JOSEPTÉ: 0.9257
#  JOSEPTÈ: 0.9257
#  JOSEUTÈ: 0.8389
#  JOSEUTE: 0.8389
#  JOSEUTÉ: 0.8389
#  JOSEUTÊ: 0.8389
#  JOSEUTEU: 0.8373
#  JOSÊTEU: 0.8348
#  JOSÈTEU: 0.8348
#  JOSETEU: 0.8348
#  JOSÉTEU: 0.8348
#  JOSEPÊ: 0.8295
#  JOSÉPE: 0.8295
#  JOSEPE: 0.8295
#  JOSÈPE: 0.8295
#  JOSÊPE: 0.8295
#  JOSEPÈ: 0.8295
#  JOSEPÉ: 0.8295
#  JOSEUPTE: 0.8208
#  JOSEUPTÊ: 0.8208
#  JOSEUPTÈ: 0.8208
#  JOSEUPTÉ: 0.8208
#  JOSÊPTEU: 0.8179
#  JOSÉPTEU: 0.8179
#  JOSÈPTEU: 0.8179
#  JOSEPTEU: 0.8179
#  JAUSETE: 0.8054
#  JAUSEUTE: 0.7963
#  JAUSETEU: 0.7828
#  JAUSEPTE: 0.7813
#  JOSEUPE: 0.7674
#  JOSEUPTEU: 0.7670
#  JAUSEUTEU: 0.7592
#  JOSEPEU: 0.7506
#  JAUSEUPTE: 0.7505
#  JAUSEPTEU: 0.7348
#  JOZETE: 0.7281
#  JOZETÊ: 0.7281
#  JOZÊTE: 0.7281
#  JOZÈTE: 0.7281
#  JOZETÈ: 0.7281
#  JOZETÉ: 0.7281
#  JOZÉTE: 0.7281
#  JOSEUPEU: 0.7133
#  JOZEPTE: 0.6841
#  JOZEUTE: 0.6699
#  JOZEUTEU: 0.6623
#  JOZETEU: 0.6557
#  JOZEUPTE: 0.6314
#  JOZEPTEU: 0.6265
#  JOZEPE: 0.5983
#  JOZEUPTEU: 0.5918
#
#
# query : josiane
# candidates:
#  JOSIANÊ: 1.0000
#  JOSIANÈ: 1.0000
#  JOSIANÉ: 1.0000
#  JOSIANE: 1.0000
#  JOSIAMÉ: 0.9512
#  JOSIAME: 0.9512
#  JOSIAMÊ: 0.9512
#  JOSIAMÈ: 0.9512
#  JOSIANEU: 0.9453
#  JOSIAMEU: 0.9065
#  JAUSIANE: 0.8912
#  JAUSIANÉ: 0.8912
#  JAUSIANÈ: 0.8912
#  JAUSIANÊ: 0.8912
#  JOSYANÊ: 0.8811
#  JOSYANÈ: 0.8811
#  JOSYANÉ: 0.8811
#  JOSYANE: 0.8811
#  JOSYANEU: 0.8763
#  JAUSIANEU: 0.8740
#  JOSYAMEU: 0.8413
#  JAUSIAMEU: 0.8343
#  JAUSIAME: 0.8343
#  JOSYAME: 0.8283
#  JAUSYANEU: 0.8058
#  JAUSYANE: 0.7954
#  JOZIANÉ: 0.7821
#  JOZIANÈ: 0.7821
#  JOZIANE: 0.7821
#  JOZIANÊ: 0.7821
#  JOZIANEU: 0.7710
#  JOZIAMEU: 0.7576
#  JOZIAME: 0.7564
#  JAUZIANE: 0.7406
# JOZYANEU: 0.7217
#  JAUZIANEU: 0.7172
#  JOZYANE: 0.6728
#
#
# query : jourdain
# candidates:
#  JOURDAIN: 1.0000
#  JOURDAIM: 0.9089
# GOURDAIN: 0.8149
#  GOURDAIM: 0.7710
#
#
# query : jules
# candidates:
#  JULÉS: 1.0000
#  JULÈS: 1.0000
#  JULES: 1.0000
#  JULÊS: 1.0000
#  JULEUS: 0.9717
# JULÉX: 0.8408
#  JULÊX: 0.8408
#  JULÈX: 0.8408
#  JULEX: 0.8408
#  JULEUX: 0.8337
#  JULÉD: 0.8190
#  JULED: 0.8190
#  JULÊD: 0.8190
#  JULÈD: 0.8190
#  JULEUD: 0.7991
#
#
# query : juliane
# candidates:
#  JULIANÈ: 1.0000
#  JULIANÊ: 1.0000
#  JULIANÉ: 1.0000
#  JULIANE: 1.0000
#  JULIANEU: 0.9750
#  JULIAMÊ: 0.9507
#  JULIAME: 0.9507
#  JULIAMÉ: 0.9507
#  JULIAMÈ: 0.9507
# JULYANÉ: 0.9446
#  JULYANÊ: 0.9446
#  JULYANE: 0.9446
#  JULYANÈ: 0.9446
#  JULYANEU: 0.9384
#  JULIAMEU: 0.9329
#  JULYAMEU: 0.8822
#  JULYAME: 0.8740
#
#
# query : julie
# candidates:
#  JULIÉ: 1.0000
#  JULIÈ: 1.0000
#  JULIÊ: 1.0000
#  JULIE: 1.0000
# JULIEU: 0.9707
#  JULYÈ: 0.9236
#  JULYE: 0.9236
#  JULYÊ: 0.9236
#  JULYÉ: 0.9236
#  JULYEU: 0.9233
#
#
# query : julien
# candidates:
#  JULIÉN: 1.0000
#  JULIÈN: 1.0000
#  JULIÊN: 1.0000
#  JULIEN: 1.0000
#  JULIEUN: 0.9750
#  JULYEUN: 0.9395
#  JULYÈN: 0.9382
#  JULYEN: 0.9382
#  JULYÉN: 0.9382
#  JULYÊN: 0.9382
#  JULIÈM: 0.9040
#  JULIÉM: 0.9040
#  JULIÊM: 0.9040
#  JULIEM: 0.9040
#  JULIEUM: 0.9017
# JULYEUM: 0.8736
#  JULYEM: 0.8567
#
#
# query : julienne
# candidates:
#  JULIENNÈ: 1.0000
#  JULIENNÊ: 1.0000
#  JULIENNÉ: 1.0000
#  JULIENNE: 1.0000
#  JULIENNEU: 0.9680
#  JULYENNÉ: 0.9559
#  JULYENNÈ: 0.9559
#  JULYENNE: 0.9559
#  JULYENNÊ: 0.9559
#  JULYENNEU: 0.9456
#  JULIEMNÉ: 0.9391
#  JULIEMNE: 0.9391
#  JULIEMNÊ: 0.9391
#  JULIEMNÈ: 0.9391
#  JULIEMNEU: 0.9339
#  JULIENME: 0.9338
#  JULIENMÉ: 0.9338
#  JULIENMÈ: 0.9338
#  JULIENMÊ: 0.9338
#  JULIENMEU: 0.9119
#  JULYENMÈ: 0.9068
#  JULYENME: 0.9068
#  JULYENMÉ: 0.9068
#  JULYENMÊ: 0.9068
#  JULYENMEU: 0.8974
#  JULYEMNEU: 0.8963
#  JULYEMNE: 0.8929
#  JULYEMNÉ: 0.8929
#  JULYEMNÈ: 0.8929
#  JULYEMNÊ: 0.8929
#  JULIEMMEU: 0.8489
#  JULIEMMÊ: 0.8307
#  JULIEMMÈ: 0.8307
#  JULIEMME: 0.8307
# JULIEMMÉ: 0.8307
#  JULYEMME: 0.8011
#
#
# query : juliette
# candidates:
#  JULIÊTE: 0.9705
#  JULIETÉ: 0.9705
#  JULIÉTÉ: 0.9705
#  JULIÉTÈ: 0.9705
#  JULIÈTÈ: 0.9705
#  JULIÈTÉ: 0.9705
#  JULIÊTÈ: 0.9705
#  JULIÈTE: 0.9705
#  JULIETE: 0.9705
#  JULIETÊ: 0.9705
#  JULIÈTÊ: 0.9705
#  JULIÉTÊ: 0.9705
#  JULIÊTÊ: 0.9705
#  JULIÉTE: 0.9705
#  JULIÊTÉ: 0.9705
#  JULIETÈ: 0.9705
#  JULYETE: 0.9409
#  JULYETÉ: 0.9409
#  JULYÊTE: 0.9409
#  JULYETÊ: 0.9409
#  JULYÈTE: 0.9409
#  JULYETÈ: 0.9409
#  JULYÉTE: 0.9409
#  JULIEUTÊ: 0.9393
#  JULIEUTÈ: 0.9393
#  JULIEUTÉ: 0.9393
#  JULIEUTE: 0.9393
#  JULIÉTEU: 0.9270
#  JULIÈTEU: 0.9270
#  JULIÊTEU: 0.9270
#  JULIETEU: 0.9270
#  JULIEPTÈ: 0.9197
#  JULIÊPTÊ: 0.9197
#  JULIEPTE: 0.9197
#  JULIÈPTÈ: 0.9197
#  JULIÊPTE: 0.9197
#  JULIÈPTÊ: 0.9197
#  JULIÊPTÈ: 0.9197
#  JULIEPTÊ: 0.9197
#  JULIÉPTÈ: 0.9197
#  JULIEPTÉ: 0.9197
#  JULIÉPTE: 0.9197
#  JULIÉPTÉ: 0.9197
#  JULIÊPTÉ: 0.9197
#  JULIÈPTE: 0.9197
#  JULIÈPTÉ: 0.9197
#  JULIÉPTÊ: 0.9197
#  JULIEUTEU: 0.9080
#  JULYEUTÉ: 0.9054
#  JULYEUTÊ: 0.9054
#  JULYEUTE: 0.9054
#  JULYEUTÈ: 0.9054
#  JULYÉTEU: 0.9040
#  JULYÊTEU: 0.9040
#  JULYÈTEU: 0.9040
#  JULYETEU: 0.9040
#  JULYEUTEU: 0.8843
#  JULIEUPTÈ: 0.8759
#  JULIEUPTE: 0.8759
#  JULIEUPTÉ: 0.8759
#  JULIEUPTÊ: 0.8759
#  JULIÈPTEU: 0.8738
#  JULIÉPTEU: 0.8738
#  JULIEPTEU: 0.8738
#  JULIÊPTEU: 0.8738
#  JULYEPTÊ: 0.8736
#  JULYEPTÈ: 0.8736
#  JULYÈPTE: 0.8736
#  JULYÉPTE: 0.8736
#  JULYEPTE: 0.8736
#  JULYÊPTE: 0.8736
#  JULYEPTÉ: 0.8736
#  JULYEPTEU: 0.8557
#  JULYEUPTE: 0.8466
#  JULIEUPTEU: 0.8430
#  JULYEUPTEU: 0.8267
#  JULIEPÈ: 0.8186
#  JULIEPÉ: 0.8186
#  JULIÉPE: 0.8186
#  JULIEPE: 0.8186
#  JULIEPÊ: 0.8186
#  JULIÊPE: 0.8186
#  JULIÈPE: 0.8186
# JULIEUPÊ: 0.7946
#  JULIEUPÈ: 0.7946
#  JULIEUPE: 0.7946
#  JULIEUPÉ: 0.7946
#  JULIEPEU: 0.7916
#  JULIÉPEU: 0.7916
#  JULIÊPEU: 0.7916
#  JULIÈPEU: 0.7916
#  JULYEPEU: 0.7666
#  JULYEPE: 0.7630
#  JULYEUPE: 0.7620
#  JULIEUPEU: 0.7580
#
#
# query : juste
# candidates:
#  JUSTÊ: 1.0000
#  JUSTÈ: 1.0000
#  JUSTÉ: 1.0000
#  JUSTE: 1.0000
#  JUSSTE: 0.9772
#  JUSSTÉ: 0.9772
#  JUSSTÈ: 0.9772
#  JUSSTÊ: 0.9772
#  JUSTEU: 0.9621
#  JUSSTEU: 0.9519
#  JUSCTE: 0.9126
#  JUSCTÉ: 0.9126
#  JUSCTÈ: 0.9126
#  JUSCTÊ: 0.9126
#  JUSCTEU: 0.9026
#  JUSPTÉ: 0.8889
#  JUSPTE: 0.8889
#  JUSPTÊ: 0.8889
#  JUSPTÈ: 0.8889
#  JUSSPTÊ: 0.8882
#  JUSSPTÉ: 0.8882
#  JUSSPTÈ: 0.8882
#  JUSSPTE: 0.8882
#  JUSSPTEU: 0.8706
#  JUSPTEU: 0.8627
#  JUSPÉ: 0.8536
#  JUSPÊ: 0.8536
#  JUSPÈ: 0.8536
#  JUSPE: 0.8536
# JUSCPTÉ: 0.8515
#  JUSCPTÈ: 0.8515
#  JUSCPTÊ: 0.8515
#  JUSCPTE: 0.8515
#  JUSCPTEU: 0.8486
#  JUSSPE: 0.8442
#  JUSPEU: 0.8410
#  JUSSPEU: 0.8405
#  JUSCPEU: 0.8036
#  JUSCPE: 0.8015

# %%
ranked_list('rejected_names.csv')
# Out:
# query : absolon
# candidates:
#  ABSSAULAUN: 0.9020
#  ABSCAULAUN: 0.8622
#  ABSSAULAUM: 0.8302
#  ABSAULAUM: 0.8301
#  ABSCAULAUM: 0.7966
# ABCOLAUN: 0.7890
#  ABCOLON: 0.7888
#  ABCAULON: 0.7871
#  ABCAULAUN: 0.7518
#  ABCAULOM: 0.7466
#  ABCOLAUM: 0.7324
#  ABCOLOM: 0.7244
#  ABCAULAUM: 0.6978
#
#
# query : achille
# candidates:
# ASCHILLE: 0.8871
#  ASCHILE: 0.8764
#  ACHYE: 0.8082
#  ASCHYE: 0.7303
#  ASHYE: 0.6797
#  ACHY: 0.6699
#  ASCHY: 0.6025
#  ASHY: 0.5289
#
#
# query : adèle
# candidates:
# ADEULÊ: 0.9229
#  ADEULÈ: 0.9229
#  ADEULÉ: 0.9229
#
#
# query : adeline
# candidates:
#  ADÉLYNÈ: 0.9206
#  ADÈLYNÉ: 0.9206
#  ADÊLYNÊ: 0.9206
#  ADÉLYNÊ: 0.9206
#  ADÉLYNÉ: 0.9206
#  ADÊLYNÈ: 0.9206
#  ADÊLYNÉ: 0.9206
#  ADÈLYNÈ: 0.9206
#  ADÈLYNÊ: 0.9206
#  ADÈLIMÈ: 0.9114
#  ADÊLIMÊ: 0.9114
#  ADÊLIMÈ: 0.9114
#  ADÊLIMÉ: 0.9114
#  ADÉLIMÊ: 0.9114
#  ADÉLIMÈ: 0.9114
#  ADÈLIMÉ: 0.9114
#  ADÈLIMÊ: 0.9114
#  ADÉLIMÉ: 0.9114
#  ADEULYMÊ: 0.8859
#  ADEULYMÉ: 0.8859
#  ADEULYMÈ: 0.8859
#  ADÈLYMEU: 0.8286
#  ADÉLYMEU: 0.8286
#  ADÊLYMEU: 0.8286
# ADÊLYMÈ: 0.8154
#  ADÈLYMÊ: 0.8154
#  ADELYMÈ: 0.8154
#  ADÉLYMÊ: 0.8154
#  ADÊLYMÊ: 0.8154
#  ADÊLYMÉ: 0.8154
#  ADELYMÊ: 0.8154
#  ADÈLYME: 0.8154
#  ADÈLYMÈ: 0.8154
#  ADÉLYMÈ: 0.8154
#  ADÈLYMÉ: 0.8154
#  ADELYMÉ: 0.8154
#  ADÊLYME: 0.8154
#  ADÉLYME: 0.8154
#  ADÉLYMÉ: 0.8154
#
#
# query : adolphe
# candidates:
# ADAULFÈ: 0.7254
#  ADAULFÉ: 0.7254
#  ADAULFE: 0.7254
#  ADAULFÊ: 0.7254
#  ADAULVÈ: 0.7200
#  ADAULVÊ: 0.7200
#  ADAULVÉ: 0.7200
#  ADAULVE: 0.7200
#  ADAULFEU: 0.7099
#  ADAULVEU: 0.7010
#
#
# query : amaury
# candidates:
# AMORI: 0.7918
#  ANORY: 0.7116
#  ANORI: 0.6369
#
#
# query : ambre
# candidates:
#  ONBRÈ: 0.8026
#  ONBRÉ: 0.8026
# ONBRÊ: 0.8026
#  ONBREU: 0.6940
#
#
# query : ambroise
# candidates:
#  ONBROYSÉ: 0.8439
#  ONBROYSÊ: 0.8439
#  ONBROYSÈ: 0.8439
#  ONBROYSEU: 0.8325
# ONBROIZÊ: 0.8163
#  ONBROIZÈ: 0.8163
#  ONBROIZÉ: 0.8163
#  ONBROIZEU: 0.7646
#  ANBROYZEU: 0.7621
#  ONBROYZEU: 0.7490
#  ONBROYZE: 0.7348
#  ONBROYZÈ: 0.7348
#  ONBROYZÊ: 0.7348
#  ONBROYZÉ: 0.7348
#  ANBROYZÊ: 0.7314
#  ANBROYZÈ: 0.7314
#  ANBROYZÉ: 0.7314
#
#
# query : amédée
# candidates:
#  AMÈDÊ: 0.9924
#  AMEDÈ: 0.9924
#  AMÊDÈ: 0.9924
#  AMÊDÊ: 0.9924
#  AMÈDÈ: 0.9924
#  AMEDÊ: 0.9924
#  AMEUDÊ: 0.9242
#  AMEUDÈ: 0.9242
# ANÈDÊ: 0.8410
#  ANÉDÈ: 0.8410
#  ANÊDE: 0.8410
#  ANEDE: 0.8410
#  ANÊDÊ: 0.8410
#  ANEDÈ: 0.8410
#  ANÈDÈ: 0.8410
#  ANÉDÊ: 0.8410
#  ANEDÉ: 0.8410
#  ANEDÊ: 0.8410
#  ANÊDÈ: 0.8410
#  ANÈDÉ: 0.8410
#  ANÈDE: 0.8410
#  ANÊDÉ: 0.8410
#  ANEUDE: 0.7520
#  ANEUDÊ: 0.7520
#  ANEUDÈ: 0.7520
#  ANEUDÉ: 0.7520
#  ANÈDEU: 0.7492
#  ANÊDEU: 0.7492
#  ANEDEU: 0.7492
#  ANEUDEU: 0.7489
#
#
# query : anne
# candidates:
# ONNÉ: 0.8932
#  ONNÊ: 0.8932
#  ONNÈ: 0.8932
#  AMNÊ: 0.8479
#  AMNÈ: 0.8479
#  AMNÉ: 0.8479
#  ANMÊ: 0.8249
#  ANMÈ: 0.8249
#  ANMÉ: 0.8249
#  ONMÈ: 0.7602
#  ONME: 0.7602
#  ONMÉ: 0.7602
#  ONMÊ: 0.7602
#  ONMEU: 0.6612
#  AMME: 0.6068
#  AMMÊ: 0.6068
#  AMMÈ: 0.6068
#  AMMÉ: 0.6068
#  AMMEU: 0.5849
#
#
# query : arianne
# candidates:
#  ARIONMÈ: 0.9217
#  ARIONMÊ: 0.9217
#  ARIONMÉ: 0.9217
#  ARYONNÈ: 0.8955
#  ARYONNÉ: 0.8955
#  ARYONNÊ: 0.8955
#  ARYONMÈ: 0.8491
#  ARYONMÊ: 0.8491
#  ARYONME: 0.8491
#  ARYONMÉ: 0.8491
#  ARYANMÊ: 0.8370
#  ARYANMÈ: 0.8370
#  ARYANMÉ: 0.8370
#  ARIAMMÊ: 0.8320
#  ARIAMMÉ: 0.8320
#  ARIAMMÈ: 0.8320
#  ARYAMNÉ: 0.8182
#  ARYAMNÊ: 0.8182
#  ARYAMNÈ: 0.8182
#  ARYONMEU: 0.8091
# ARYAMMEU: 0.7752
#  ARYAMME: 0.7345
#  ARYAMMÊ: 0.7345
#  ARYAMMÈ: 0.7345
#  ARYAMMÉ: 0.7345
#
#
# query : arienne
# candidates:
#  ARYENMÊ: 0.8587
#  ARYENMÉ: 0.8587
#  ARYENMÈ: 0.8587
#  ARYEMNÈ: 0.8492
#  ARYEMNÊ: 0.8492
#  ARYEMNÉ: 0.8492
#  ARIEMMÉ: 0.8063
#  ARIEMMÈ: 0.8063
#  ARIEMMÊ: 0.8063
#  ARYEMMEU: 0.7884
# ARYEMMÈ: 0.7560
#  ARYEMMÊ: 0.7560
#  ARYEMME: 0.7560
#  ARYEMMÉ: 0.7560
#
#
# query : arlette
# candidates:
# ARLÈPTÉ: 0.9094
#  ARLÊPTÊ: 0.9094
#  ARLÈPTÈ: 0.9094
#  ARLÉPTÊ: 0.9094
#  ARLÉPTÉ: 0.9094
#  ARLÈPTÊ: 0.9094
#  ARLÊPTÈ: 0.9094
#  ARLÊPTÉ: 0.9094
#  ARLÉPTÈ: 0.9094
#  ARLÉPÈ: 0.7922
#  ARLÈPÈ: 0.7922
#  ARLÈPÉ: 0.7922
#  ARLÉPÊ: 0.7922
#  ARLÉPÉ: 0.7922
#  ARLÊPÉ: 0.7922
#  ARLÊPÈ: 0.7922
#  ARLÊPÊ: 0.7922
#  ARLÈPÊ: 0.7922
#  ARLEUPÊ: 0.7585
#  ARLEUPÈ: 0.7585
#  ARLEUPÉ: 0.7585
#  ARLÊPEU: 0.7441
#  ARLÉPEU: 0.7441
#  ARLÈPEU: 0.7441
#
#
# query : armand
# candidates:
#  ARMAN: 0.9244
#  ARNAM: 0.9038
#  ARMANB: 0.8746
#  ARMANC: 0.8648
#  ARNAMT: 0.8610
#  ARNAMS: 0.8607
#  ARMON: 0.8599
#  ARNAMB: 0.8509
#  ARMAM: 0.8410
#  ARNAMC: 0.8407
#  ARNAMP: 0.8359
#  ARNAMX: 0.8238
#  ARMONC: 0.8200
#  ARMONB: 0.8043
#  ARNAN: 0.8038
#  ARMAMB: 0.7938
#  ARMAMC: 0.7785
# ARNON: 0.7581
#  ARNANB: 0.7388
#  ARNANC: 0.7282
#  ARNONT: 0.7169
#  ARNONS: 0.7084
#  ARNONB: 0.6947
#  ARNONP: 0.6930
#  ARNONC: 0.6845
#  ARNONX: 0.6623

# %%
rank_name_variations(df['Fr_names'][i], df['variations'][i])

# %%
df = pd.read_csv("names_.csv")


df['variations'] = df['variations'].apply(lambda x: x.split(',') if isinstance(x, str) else [])

df.head()
for i in range(len(df)):
    ranked_list = rank_name_variations(df['name'][i], df['variations'][i])
    print('\n')
    print('query :', df['name'][i])
    print('candidates:')
    for var, score in ranked_list:
        print(f"{var}: {score:.4f}")
# Out:
# query : Michael
# candidates:
#  Micheal: 0.9940
#  Michel: 0.9812
#  Michal: 0.9503
#  Mikael: 0.7570
# Mike: 0.6804
#  Mikey: 0.6581
#
#
# query : Elizabeth
# candidates:
#  Eliza: 0.8430
#  Beth: 0.7691
#  Liza: 0.7577
# Liz: 0.7280
#  Lizzy: 0.7033
#  Eli: 0.6335
#
#
# query : Jonathan
# candidates:
#  Jhonathan: 0.9847
# John: 0.8374
#  Johnny: 0.8179
#  Jona: 0.6978
#  Jon: 0.6677
#  Jonny: 0.6495
#
#
# query : Katherine
# candidates:
#  Katherin: 0.9882
#  Katie: 0.8810
#  Kathryn: 0.8734
# Kate: 0.8481
#  Kath: 0.8056
#  Kathy: 0.7943
#
#
# query : William
# candidates:
#  Willam: 0.9727
#  Wiliam: 0.9718
# Will: 0.8032
#  Willy: 0.7867
#  Bill: 0.6352
#  Billy: 0.6310
#
#
# query : Christopher
# candidates:
#  Cristopher: 0.9611
# Chris: 0.8482
#  Topher: 0.8326
#  Chrissy: 0.8008
#  Kristopher: 0.7935
#
#
# query : Alexander
# candidates:
#  Xander: 0.9325
# Alex: 0.7961
#  Lex: 0.7641
#  Alejandro: 0.7640
#  Aleksander: 0.7490
#
#
# query : Jennifer
# candidates:
#  Jeni: 0.7679
# Jen: 0.7615
#  Jenn: 0.7570
#  Jenna: 0.7330
#  Jenny: 0.7067
#
#
# query : Robert
# candidates:
#  Roberto: 0.9576
#  Robbie: 0.8500
# Rob: 0.7771
#  Bob: 0.6091
#  Bobby: 0.5877
#
#
# query : Matthew
# candidates:
#  Mathew: 0.9878
#  Matheu: 0.8920
#  Matty: 0.7810
# Matt: 0.7670
#  Mat: 0.7415
#
#
# query : Jean
# candidates:
#  Jeanno: 0.9065
#  Jeanot: 0.8476
#  Jehan: 0.8417
# Jeannot: 0.8327
#
#
# query : François
# candidates:
#  Francois: 1.0000
#  Francis: 0.9421
#  Françoys: 0.9139
# Franck: 0.6898
#
#
# query : Charlotte
# candidates:
#  Charlott: 0.9302
#  Charlot: 0.9211
# Lotte: 0.7823
#  Charly: 0.7061
#
#
# query : Guillaume
# candidates:
#  Gillaume: 0.9816
# Guilhem: 0.8883
#  Gui: 0.8301
#  William: 0.6761
#
#
# query : Théo
# candidates:
#  Theo: 1.0000
#  Teo: 0.8819
# Théophile: 0.8666
#
#
# query : Sophie
# candidates:
#  Sophia: 0.9165
#  Sophy: 0.8348
# Soph: 0.8311
#  Sofie: 0.7989
#
#
# query : Nicolas
# candidates:
#  Nicolas: 1.0000
#  Nikola: 0.7687
# Nico: 0.7375
#  Nick: 0.5723
#
#
# query : Élodie
# candidates:
#  Lodie: 0.9777
#  Elodi: 0.9727
#  Elodia: 0.9613
# Elo: 0.8186
#
#
# query : Benoît
# candidates:
#  Benoit: 1.0000
#  Benoist: 0.9622
# Ben: 0.7569
#  Benny: 0.7558
#
#
# query : Céline
# candidates:
# Celin: 0.9780
#  Celina: 0.9511
#  Célinette: 0.8165
#  Lina: 0.6894
#
#
# query : Giovanni
# candidates:
#  Giovanny: 0.9614
#  Gianni: 0.8452
# Gio: 0.8063
#  Vanni: 0.7096
#
#
# query : Francesca
# candidates:
#  Franceska: 0.9052
# Franci: 0.8277
#  Fran: 0.7585
#  Cesca: 0.7330
#
#
# query : Alessandro
# candidates:
#  Alessandrino: 0.9809
# Alessio: 0.9176
#  Sandro: 0.8676
#  Alex: 0.5054
#
#
# query : Giulia
# candidates:
# Giuli: 0.9719
#  Giulietta: 0.8803
#  Julie: 0.6646
#  Julietta: 0.6247
#
#
# query : Matteo
# candidates:
#  Mattia: 0.7836
#  Matt: 0.7814
# Teo: 0.7802
#  Mat: 0.7737
#
#
# query : Lorenzo
# candidates:
#  Lorenzino: 0.9701
#  Renzo: 0.8933
# Enzo: 0.8233
#  Lory: 0.7144
#
#
# query : Giuseppe
# candidates:
#  Giusi: 0.7401
#  Peppino: 0.7306
#  Peppe: 0.7266
# Beppe: 0.6286
#
#
# query : Angela
# candidates:
#  Angel: 0.9658
#  Angelina: 0.9647
#  Angie: 0.8894
# Angy: 0.7715
#
#
# query : Stefano
# candidates:
#  Stef: 0.8758
#  Stefanuccio: 0.8724
# Ste: 0.7816
#  Stevy: 0.6621
#
#
# query : Roberto
# candidates:
#  Robertino: 0.9655
#  Berto: 0.9523
# Robi: 0.7918
#  Robby: 0.7473
